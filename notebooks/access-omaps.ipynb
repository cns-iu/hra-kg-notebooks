# %% [markdown]
# ## Code to access Organ Mapping Antibody Panels (OMAPs) via the HRA Knowledge Graph (KG)

# %% [markdown]
# ## Install and import libraries

# %%
# %%capture
# %pip install requests

import requests
from pprint import pprint
import warnings
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
# Out:
# Requirement already satisfied: requests in c:\users\abueckle\documents\github\hra-kg-notebooks\.venv\lib\site-packages (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\abueckle\documents\github\hra-kg-notebooks\.venv\lib\site-packages (from requests) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\abueckle\documents\github\hra-kg-notebooks\.venv\lib\site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\abueckle\documents\github\hra-kg-notebooks\.venv\lib\site-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\abueckle\documents\github\hra-kg-notebooks\.venv\lib\site-packages (from requests) (2025.6.15)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## 1. Manual download

# %% [markdown]
# You can download OMAPs as CSV files by navigating to [https://humanatlas.io/omap#summary-statistics](https://humanatlas.io/omap#summary-statistics), choosing an OMAP of your choice, e.g. OMAP-2, then clicking the CSV download button, which will take you to [https://cdn.humanatlas.io/digital-objects/omap/2-intestine-codex/v1.6/assets/omap-2-intestine-codex.csv](https://cdn.humanatlas.io/digital-objects/omap/2-intestine-codex/v1.6/assets/omap-2-intestine-codex.csv). A prompt for the download will pop up.

# %% [markdown]
# ## 2. Programmatic download via HRA KG

# %% [markdown]
# This code sets up access via the HRA KG using Pythons `requests` library.

# %%
# Each HRA DO has a persistent URL (PURL), where the user is served HRA DO data after server-side content negotation
# This is the base URL for PURLs for OMAPs, see https://lod.humanatlas.io/omap/
base_url = 'https://purl.humanatlas.io/omap/'

def download_omap(omap_name:str):
  """
  Download and return JSON data for a given OMAP name from the base URL of the HRA LOD Server.

  Args:
    omap_name (str): The identifier or name of the OMAP to be downloaded.

  Returns:
    dict: The parsed JSON response from the server, depending on the API structure.

  Raises:
    HTTPError: If the HTTP request returned an unsuccessful status code.
    ConnectionError: If there was a network problem (e.g., DNS failure, refused connection).
    Timeout: If the request timed out.
    RequestException: For other ambiguous exceptions during the request process.
  """
  
  # set headers for web request
  headers = {
      "Accept": "application/json"
  }
  
  url = base_url+omap_name
  
  try:
    response = requests.get(url, headers=headers)
    
    response.raise_for_status()  # Raises HTTPError for bad responses (4xx or 5xx)
    # response_json = requests.get(url, timeout=10).json()  # 10 seconds timeout
    
    data = response.json()  # Or use response.text for raw content
    pprint(type(data))
    return data
  except requests.exceptions.HTTPError as errh:
      print(f"HTTP error: {errh}")
  except requests.exceptions.ConnectionError as errc:
      print(f"Connection error: {errc}")
  except requests.exceptions.Timeout as errt:
      print(f"Timeout error: {errt}")
  except requests.exceptions.RequestException as err:
      print(f"Request failed: {err}")

# %%
# let's request the latest CODEX OMAP for intestine (OMAP-2)
from pprint import pprint
intestine_omap = download_omap('2-intestine-codex')

# Pretty print the result
pprint(dict(list(intestine_omap.items())[:10]))
# Out:
# <class 'dict'>
# {'$schema': 'https://cdn.humanatlas.io/digital-objects/schema/omap/latest/assets/schema.json',
#  '@context': 'https://cdn.humanatlas.io/digital-objects/schema/omap/latest/assets/schema.context.jsonld',
#  '@type': 'Container',
#  'data': {'antibody': [{'antibody_type': 'Primary',
#                         'catalog_number': '556003',
#                         'clonality': 'Monoclonal',
#                         'clone_id': 'B56',
#                         'conjugate': 'Oligonucleotide',
#                         'detects': [{'protein_id': ['HGNC:7107'],
#                                      'rationale': 'This marker does not define '
#                                                   'a distinct cell type, but '
#                                                   'highlights all '
#                                                   'proliferating cells, useful '
#                                                   'in various diseases and '
#                                                   'transit amplifying cells. '
#                                                   'Defines germinal centers of '
#                                                   'gut-associated lymphoid '
#                                                   'tissue (GALT). This marker '
#                                                   'represents a prioritized '
#                                                   'target in the intestine '
#                                                   'OMAP.'}],
#                         'fluorescent': 'AF488',
#                         'host': 'Mouse',
#                         'id': 'https://identifiers.org/RRID:AB_396287',
#                         'isotype': 'IgG1 kappa',
#                         'parent_class': 'ccf:Antibody',
#                         'producer': 'BD Biosciences',
#                         'recombinant': 'N'},
#                        {'antibody_type': 'Primary',
#                         'catalog_number': 'BE0014',
#                         'clonality': 'Monoclonal',
#                         'clone_id': '7G7B6',
#                         'conjugate': 'Oligonucleotide',
#                         'detects': [{'protein_id': ['HGNC:6008'],
#                                      'rationale': 'This marker can be used to '
#                                                   'identify T regulatory '
#                                                   'cells. The inclusion of '
#                                                   'FOXP3 is recommended to '
#                                                   'provide greater confidence '
#                                                   'in the T regulatory cell '
#                                                   'phenotype. This marker '
#                                                   'represents a prioritized '
#                                                   'target in the intestine '
#                                                   'OMAP.'}],
#                         'fluorescent': 'Cy3',
#                         'host': 'Mouse',
#                         'id': 'https://identifiers.org/RRID:AB_1107617',
#                         'isotype': 'IgG2a',
#                         'parent_class': 'ccf:Antibody',
#                         'producer': 'Bio X Cell',
#                         'recombinant': 'N'},
#                        {'antibody_type': 'Primary',
#                         'catalog_number': '315602',
#                         'clonality': 'Monoclonal',
#                         'clone_id': 'MEM-108',
#                         'conjugate': 'Oligonucleotide',
#                         'detects': [{'protein_id': ['HGNC:11026'],
#                                      'rationale': 'This marker does not define '
#                                                   'a distinct cell type but '
#                                                   'instead serves as a '
#                                                   'pan-membrane marker. It can '
#                                                   'be used to segment most '
#                                                   'cells.'}],
#                         'fluorescent': 'Cy5',
#                         'host': 'Mouse',
#                         'id': 'https://identifiers.org/RRID:AB_2302070',
#                         'isotype': 'IgG1 kappa',
#                         'parent_class': 'ccf:Antibody',
#                         'producer': 'BioLegend',
#                         'recombinant': 'N'},
#                        {'antibody_type': 'Primary',
#                         'catalog_number': '550513',
#                         'clonality': 'Monoclonal',
#                         'clone_id': 'RV202',
#                         'conjugate': 'Oligonucleotide',
#                         'detects': [{'protein_id': ['HGNC:12692'],
#                                      'rationale': 'Defines stromal network of '
#                                                   'intestine and serves as a '
#                                                   'pan-mesenchymal cell '
#                                                   'marker. The combination of '
#                                                   'collagen IV, '
#                                                   'pan-cytokeratin, alpha '
#                                                   'smooth muscle actin, and '
#                                                   'vimentin can be used to '
#                                                   'define the villi, crypts, '
#                                                   'basal membrane, and lamina '
#                                                   'propria. This marker '
#                                                   'represents a core panel and '
#                                                   'prioritized target in the '
#                                                   'intestine OMAP.'}],
#                         'fluorescent': 'AF488',
#                         'host': 'Mouse',
#                         'id': 'https://identifiers.org/RRID:AB_393716',
#                         'isotype': 'IgG1',
#                         'parent_class': 'ccf:Antibody',
#                         'producer': 'BD Biosciences',
#                         'recombinant': 'N'},
#                        {'antibody_type': 'Primary',
#                         'catalog_number': '322302',
#                         'clonality': 'Monoclonal',
#                         'clone_id': 'HCD57',
#                         'conjugate': 'Oligonucleotide',
#                         'detects': [{'protein_id': ['HGNC:921'],
#                                      'rationale': 'Used for identification of '
#                                                   'NK cells.'}],
#                         'fluorescent': 'Cy3',
#                         'host': 'Mouse',
#                         'id': 'https://identifiers.org/RRID:AB_535988',
#                         'isotype': 'IgM',
#                         'parent_class': 'ccf:Antibody',
#                         'producer': 'BioLegend',
#                         'recombinant': 'N'},
#                        {'antibody_type': 'Primary',
#                         'catalog_number': '320802',
#                         'clonality': 'Monoclonal',
#                         'clone_id': '1D11',
#                         'conjugate': 'Oligonucleotide',
#                         'detects': [{'protein_id': ['HGNC:18788'],
#                                      'rationale': 'Used for identification of '
#                                                   'NK cells.'}],
#                         'fluorescent': 'Cy5',
#                         'host': 'Mouse',
#                         'id': 'https://identifiers.org/RRID:AB_492956',
#                         'isotype': 'IgG1 kappa',
#                         'parent_class': 'ccf:Antibody',
#                         'producer': 'BioLegend',
#                         'recombinant': 'N'},
#                        {'antibody_type': 'Primary',
#                         'catalog_number': '343102',
#                         'clonality': 'Monoclonal',
#                         'clone_id': 'CD7-6B7',
#                         'conjugate': 'Oligonucleotide',
#                         'detects': [{'protein_id': ['HGNC:1695'],
#                                      'rationale': 'Used for identification of '
#                                                   'NK and T cells.'}],
#                         'fluorescent': 'AF488',
#                         'host': 'Mouse',
#                         'id': 'https://identifiers.org/RRID:AB_1659214',
#                         'isotype': 'IgG2a kappa',
#                         'parent_class': 'ccf:Antibody',
#                         'producer': 'BioLegend',
#                         'recombinant': 'N'},
#                        {'antibody_type': 'Primary',
#                         'catalog_number': '357402',
#                         'clonality': 'Monoclonal',
#                         'clone_id': 'A161A1',
#                         'conjugate': 'Oligonucleotide',
#                         'detects': [{'protein_id': ['HGNC:1678'],
#                                      'rationale': 'Used for identification of '
#                                                   'CD4+ T cells. This marker '
#                                                   'represents a prioritized '
#                                                   'target in the intestine '
#                                                   'OMAP.'}],
#                         'fluorescent': 'Cy3',
#                         'host': 'Rat',
#                         'id': 'https://identifiers.org/RRID:AB_2561907',
#                         'isotype': 'IgG2b kappa',
#                         'parent_class': 'ccf:Antibody',
#                         'producer': 'BioLegend',
#                         'recombinant': 'N'},
#                        {'antibody_type': 'Primary',
#                         'catalog_number': '555410',
#                         'clonality': 'Monoclonal',
#                         'clone_id': 'HIB19',
#                         'conjugate': 'Oligonucleotide',
#                         'detects': [{'protein_id': ['HGNC:1633'],
#                                      'rationale': 'Essential marker of B cells '
#                                                   'and also identifies plasma '
#                                                   'cells. Defines B cell '
#                                                   'follicles of gut-associated '
#                                                   'lymphoid tissue (GALT). '
#                                                   'This marker represents a '
#                                                   'core panel and prioritized '
#                                                   'target in the intestine '
#                                                   'OMAP.'}],
#                         'fluorescent': 'Cy5',
#                         'host': 'Mouse',
#                         'id': 'https://identifiers.org/RRID:AB_395810',
#                         'isotype': 'IgG1 kappa',
#                         'parent_class': 'ccf:Antibody',
#                         'producer': 'BD Biosciences',
#                         'recombinant': 'N'},
#                        {'antibody_type': 'Primary',
#                         'catalog_number': '307651',
#                         'clonality': 'Monoclonal',
#                         'clone_id': 'L243',
#                         'conjugate': 'Oligonucleotide',
#                         'detects': [{'protein_id': ['HGNC:1697'],
#                                      'rationale': 'Used for identification of '
#                                                   'antigen presenting cells (B '
#                                                   'cells, dendritic cells, '
#                                                   'macrophages). Defines B '
#                                                   'cell follicles (HLA-DR+) '
#                                                   'and germinal centers '
#                                                   '(HLA-DR++) of '
#                                                   'gut-associated lymphoid '
#                                                   'tissue (GALT).'}],
#                         'fluorescent': 'AF488',
#                         'host': 'Mouse',
#                         'id': 'https://identifiers.org/RRID:AB_2562826',
#                         'isotype': 'IgG2a kappa',
#                         'parent_class': 'ccf:Antibody',
#                         'producer': 'BioLegend',
#                         'recombinant': 'N'},
#                        {'antibody_type': 'Primary',
#                         'catalog_number': '555391',
#                         'clonality': 'Monoclonal',
#                         'clone_id': 'B-ly6',
#                         'conjugate': 'Oligonucleotide',
#                         'detects': [{'protein_id': ['HGNC:6152'],
#                                      'rationale': 'Used for identification of '
#                                                   'dendritic cells. This '
#                                                   'marker represents a '
#                                                   'prioritized target in the '
#                                                   'intestine OMAP.'}],
#                         'fluorescent': 'Cy3',
#                         'host': 'Mouse',
#                         'id': 'https://identifiers.org/RRID:AB_395792',
#                         'isotype': 'IgG1 kappa',
#                         'parent_class': 'ccf:Antibody',
#                         'producer': 'BD Biosciences',
#                         'recombinant': 'N'},
#                        {'antibody_type': 'Primary',
#                         'catalog_number': '339902',
#                         'clonality': 'Monoclonal',
#                         'clone_id': 'HP-3G10',
#                         'conjugate': 'Oligonucleotide',
#                         'detects': [{'protein_id': ['HGNC:6373'],
#                                      'rationale': 'Used for identification of '
#                                                   'NK cells and other innate '
#                                                   'lymphoid cells.'}],
#                         'fluorescent': 'Cy5',
#                         'host': 'Mouse',
#                         'id': 'https://identifiers.org/RRID:AB_1501090',
#                         'isotype': 'IgG1 kappa',
#                         'parent_class': 'ccf:Antibody',
#                         'producer': 'BioLegend',
#                         'recombinant': 'N'},
#                        {'antibody_type': 'Primary',
#                         'catalog_number': 'NBP1-47483',
#                         'clonality': 'Monoclonal',
#                         'clone_id': '7H12',
#                         'conjugate': 'Oligonucleotide',
#                         'detects': [{'protein_id': ['HGNC:11506'],
#                                      'rationale': 'Used for identification of '
#                                                   'neural cells. This marker '
#                                                   'represents a prioritized '
#                                                   'target in the intestine '
#                                                   'OMAP.'}],
#                         'fluorescent': 'AF488',
#                         'host': 'Mouse',
#                         'id': 'https://identifiers.org/RRID:AB_10010435',
#                         'isotype': 'IgG1',
#                         'parent_class': 'ccf:Antibody',
#                         'producer': 'Novus Biologicals',
#                         'recombinant': 'N'},
#                        {'antibody_type': 'Primary',
#                         'catalog_number': '343602',
#                         'clonality': 'Monoclonal',
#                         'clone_id': '561',
#                         'conjugate': 'Oligonucleotide',
#                         'detects': [{'protein_id': ['HGNC:1662'],
#                                      'rationale': 'Used for visualization of '
#                                                   'blood and lymphatic '
#                                                   'endothelial cells and '
#                                                   'vessels. Identifies '
#                                                   'fibroblasts of the '
#                                                   'muscularis propria and '
#                                                   'submucosa.'}],
#                         'fluorescent': 'Cy3',
#                         'host': 'Mouse',
#                         'id': 'https://identifiers.org/RRID:AB_1732014',
#                         'isotype': 'IgG2a kappa',
#                         'parent_class': 'ccf:Antibody',
#                         'producer': 'BioLegend',
#                         'recombinant': 'N'},
#                        {'antibody_type': 'Primary',
#                         'catalog_number': '555404',
#                         'clonality': 'Monoclonal',
#                         'clone_id': '3G8',
#                         'conjugate': 'Oligonucleotide',
#                         'detects': [{'protein_id': ['HGNC:3619'],
#                                      'rationale': 'Used for identification of '
#                                                   'neutrophils. This marker '
#                                                   'represents a prioritized '
#                                                   'target in the intestine '
#                                                   'OMAP.'}],
#                         'fluorescent': 'Cy5',
#                         'host': 'Mouse',
#                         'id': 'https://identifiers.org/RRID:AB_395804',
#                         'isotype': 'IgG1 kappa',
#                         'parent_class': 'ccf:Antibody',
#                         'producer': 'BD Biosciences',
#                         'recombinant': 'N'},
#                        {'antibody_type': 'Primary',
#                         'catalog_number': '555400',
#                         'clonality': 'Monoclonal',
#                         'clone_id': 'HI98',
#                         'conjugate': 'Oligonucleotide',
#                         'detects': [{'protein_id': ['HGNC:4015'],
#                                      'rationale': 'Used for identification of '
#                                                   'neutrophils. Expressed by '
#                                                   'some Paneth cells. This '
#                                                   'marker represents a '
#                                                   'prioritized target in the '
#                                                   'intestine OMAP.'}],
#                         'fluorescent': 'AF488',
#                         'host': 'Mouse',
#                         'id': 'https://identifiers.org/RRID:AB_395800',
#                         'isotype': 'IgM kappa',
#                         'parent_class': 'ccf:Antibody',
#                         'producer': 'BD Biosciences',
#                         'recombinant': 'N'},
#                        {'antibody_type': 'Primary',
#                         'catalog_number': '13-0300',
#                         'clonality': 'Monoclonal',
#                         'clone_id': '2.2B10',
#                         'conjugate': 'Oligonucleotide',
#                         'detects': [{'protein_id': ['HGNC:3590'],
#                                      'rationale': 'Used for identification of '
#                                                   'fibroblasts.'}],
#                         'fluorescent': 'Cy3',
#                         'host': 'Rat',
#                         'id': 'https://identifiers.org/RRID:AB_2532994',
#                         'isotype': 'IgG2a kappa',
#                         'parent_class': 'ccf:Antibody',
#                         'producer': 'Thermo Fisher Scientific',
#                         'recombinant': 'N'},
#                        {'antibody_type': 'Primary',
#                         'catalog_number': '554527',
#                         'clonality': 'Monoclonal',
#                         'clone_id': '7G3',
#                         'conjugate': 'Oligonucleotide',
#                         'detects': [{'protein_id': ['HGNC:6012'],
#                                      'rationale': 'Expressed by plasmacytoid '
#                                                   'dendritic cells.'}],
#                         'fluorescent': 'Cy5',
#                         'host': 'Mouse',
#                         'id': 'https://identifiers.org/RRID:AB_395455',
#                         'isotype': 'IgG2a kappa',
#                         'parent_class': 'ccf:Antibody',
#                         'producer': 'BD Biosciences',
#                         'recombinant': 'N'},
#                        {'antibody_type': 'Primary',
#                         'catalog_number': '551354',
#                         'clonality': 'Monoclonal',
#                         'clone_id': 'B1.1/CD66',
#                         'conjugate': 'Oligonucleotide',
#                         'detects': [{'protein_id': ['HGNC:1814'],
#                                      'rationale': 'Used for identification of '
#                                                   'mature epithelial cells and '
#                                                   'expressed on neutrophils'}],
#                         'fluorescent': 'AF488',
#                         'host': 'Mouse',
#                         'id': 'https://identifiers.org/RRID:AB_394166',
#                         'isotype': 'IgG2a kappa',
#                         'parent_class': 'ccf:Antibody',
#                         'producer': 'BD Biosciences',
#                         'recombinant': 'N'},
#                        {'antibody_type': 'Primary',
#                         'catalog_number': '300402',
#                         'clonality': 'Monoclonal',
#                         'clone_id': 'UCHT1',
#                         'conjugate': 'Oligonucleotide',
#                         'detects': [{'protein_id': ['HGNC:1674'],
#                                      'rationale': 'Essential marker of T '
#                                                   'cells. Defines T cell zone '
#                                                   'of gut-associated lymphoid '
#                                                   'tissues (GALT). This marker '
#                                                   'represents a core panel and '
#                                                   'prioritized target in the '
#                                                   'intestine OMAP.'}],
#                         'fluorescent': 'Cy3',
#                         'host': 'Mouse',
#                         'id': 'https://identifiers.org/RRID:AB_314056',
#                         'isotype': 'IgG1 kappa',
#                         'parent_class': 'ccf:Antibody',
#                         'producer': 'BioLegend',
#                         'recombinant': 'N'},
#                        {'antibody_type': 'Primary',
#                         'catalog_number': '304202',
#                         'clonality': 'Monoclonal',
#                         'clone_id': 'UCHL1',
#                         'conjugate': 'Oligonucleotide',
#                         'detects': [{'protein_id': ['HGNC:9666'],
#                                      'rationale': 'CD45RO is used to define a '
#                                                   'particular T cell '
#                                                   'activation state.'}],
#                         'fluorescent': 'Cy5',
#                         'host': 'Mouse',
#                         'id': 'https://identifiers.org/RRID:AB_314418',
#                         'isotype': 'IgG2a kappa',
#                         'parent_class': 'ccf:Antibody',
#                         'producer': 'BioLegend',
#                         'recombinant': 'N'},
#                        {'antibody_type': 'Primary',
#                         'catalog_number': '356602',
#                         'clonality': 'Monoclonal',
#                         'clone_id': 'HB-7',
#                         'conjugate': 'Oligonucleotide',
#                         'detects': [{'protein_id': ['HGNC:1667'],
#                                      'rationale': 'Used for identification of '
#                                                   'plasma cells. This marker '
#                                                   'represents a prioritized '
#                                                   'target in the intestine '
#                                                   'OMAP.'}],
#                         'fluorescent': 'AF488',
#                         'host': 'Mouse',
#                         'id': 'https://identifiers.org/RRID:AB_2561794',
#                         'isotype': 'IgG1 kappa',
#                         'parent_class': 'ccf:Antibody',
#                         'producer': 'BioLegend',
#                         'recombinant': 'N'},
#                        {'antibody_type': 'Primary',
#                         'catalog_number': '328102',
#                         'clonality': 'Monoclonal',
#                         'clone_id': '50000000000',
#                         'conjugate': 'Oligonucleotide',
#                         'detects': [{'protein_id': ['HGNC:11801'],
#                                      'rationale': 'Expressed by stromal cells '
#                                                   'as well as blood '
#                                                   'endothelial cells, T cells, '
#                                                   'and NK cells.'}],
#                         'fluorescent': 'Cy3',
#                         'host': 'Mouse',
#                         'id': 'https://identifiers.org/RRID:AB_940393',
#                         'isotype': 'IgG1 kappa',
#                         'parent_class': 'ccf:Antibody',
#                         'producer': 'BioLegend',
#                         'recombinant': 'N'},
#                        {'antibody_type': 'Primary',
#                         'catalog_number': '351302',
#                         'clonality': 'Monoclonal',
#                         'clone_id': 'A019D5',
#                         'conjugate': 'Oligonucleotide',
#                         'detects': [{'protein_id': ['HGNC:6024'],
#                                      'rationale': 'Used to define a particular '
#                                                   'T cell activation state.'}],
#                         'fluorescent': 'Cy5',
#                         'host': 'Mouse',
#                         'id': 'https://identifiers.org/RRID:AB_10718513',
#                         'isotype': 'IgG1 kappa',
#                         'parent_class': 'ccf:Antibody',
#                         'producer': 'BioLegend',
#                         'recombinant': 'N'},
#                        {'antibody_type': 'Primary',
#                         'catalog_number': '14-9760-82',
#                         'clonality': 'Monoclonal',
#                         'clone_id': '1A4',
#                         'conjugate': 'Oligonucleotide',
#                         'detects': [{'protein_id': ['HGNC:130'],
#                                      'rationale': 'Used for identification of '
#                                                   'smooth muscle cells. The '
#                                                   'combination of collagen IV, '
#                                                   'pan-cytokeratin, alpha '
#                                                   'smooth muscle actin, and '
#                                                   'vimentin can be used to '
#                                                   'define the villi, crypts, '
#                                                   'basal membrane, and lamina '
#                                                   'propria. This marker '
#                                                   'represents a core panel and '
#                                                   'prioritized target in the '
#                                                   'intestine OMAP.'}],
#                         'fluorescent': 'AF488',
#                         'host': 'Mouse',
#                         'id': 'https://identifiers.org/RRID:AB_2572996',
#                         'isotype': 'IgG2a kappa',
#                         'parent_class': 'ccf:Antibody',
#                         'producer': 'Thermo Fisher Scientific',
#                         'recombinant': 'N'},
#                        {'antibody_type': 'Primary',
#                         'catalog_number': '555713',
#                         'clonality': 'Monoclonal',
#                         'clone_id': 'YB5.B8',
#                         'conjugate': 'Oligonucleotide',
#                         'detects': [{'protein_id': ['HGNC:6342'],
#                                      'rationale': 'Used for identification of '
#                                                   'Interstitial cells of Cajal '
#                                                   'and mast cells. This marker '
#                                                   'represents a prioritized '
#                                                   'target in the intestine '
#                                                   'OMAP.'}],
#                         'fluorescent': 'Cy3',
#                         'host': 'Mouse',
#                         'id': 'https://identifiers.org/RRID:AB_2131466',
#                         'isotype': 'IgG1 kappa',
#                         'parent_class': 'ccf:Antibody',
#                         'producer': 'BD Biosciences',
#                         'recombinant': 'N'},
#                        {'antibody_type': 'Primary',
#                         'catalog_number': '914204',
#                         'clonality': 'Monoclonal',
#                         'clone_id': 'AE-1/AE-3',
#                         'conjugate': 'Oligonucleotide',
#                         'detects': [{'protein_id': ['HGNC:6413',
#                                                     'HGNC:6416',
#                                                     'HGNC:6421',
#                                                     'HGNC:6423',
#                                                     'HGNC:6436',
#                                                     'HGNC:6412',
#                                                     'HGNC:6439',
#                                                     'HGNC:6440',
#                                                     'HGNC:6441',
#                                                     'HGNC:6442',
#                                                     'HGNC:6445',
#                                                     'HGNC:6446'],
#                                      'rationale': 'Pan-epithelial marker for '
#                                                   'segmentation of epithelial '
#                                                   'cells. The combination of '
#                                                   'collagen IV, '
#                                                   'pan-cytokeratin, alpha '
#                                                   'smooth muscle actin, and '
#                                                   'vimentin can be used to '
#                                                   'define the villi, crypts, '
#                                                   'basal membrane, and lamina '
#                                                   'propria. This marker '
#                                                   'represents a core panel and '
#                                                   'prioritized target in the '
#                                                   'intestine OMAP.'}],
#                         'fluorescent': 'Cy5',
#                         'host': 'Mouse',
#                         'id': 'https://identifiers.org/RRID:AB_2616960',
#                         'isotype': 'IgG1 kappa',
#                         'parent_class': 'ccf:Antibody',
#                         'producer': 'BioLegend',
#                         'recombinant': 'N'},
#                        {'antibody_type': 'Primary',
#                         'catalog_number': 'V2372SAF',
#                         'clonality': 'Monoclonal',
#                         'clone_id': 'MUC1/955',
#                         'conjugate': 'Oligonucleotide',
#                         'detects': [{'protein_id': ['HGNC:7508'],
#                                      'rationale': 'Marker for epithelial '
#                                                   'cells, specifically '
#                                                   'enterocytes.'}],
#                         'fluorescent': 'AF488',
#                         'host': 'Mouse',
#                         'id': 'https://identifiers.org/RRID:AB_2864392',
#                         'isotype': 'IgG1 kappa',
#                         'parent_class': 'ccf:Antibody',
#                         'producer': 'NSJ Bioreagents',
#                         'recombinant': 'N'},
#                        {'antibody_type': 'Primary',
#                         'catalog_number': '4267',
#                         'clonality': 'Monoclonal',
#                         'clone_id': 'D38B1',
#                         'conjugate': 'Oligonucleotide',
#                         'detects': [{'protein_id': ['HGNC:1806'],
#                                      'rationale': 'Nuclear marker of '
#                                                   'intestinal epithelial cells '
#                                                   'expressed by early '
#                                                   'epithelial cells.'}],
#                         'fluorescent': 'Cy3',
#                         'host': 'Rabbit',
#                         'id': 'https://identifiers.org/RRID:AB_2864405',
#                         'isotype': 'IgG',
#                         'parent_class': 'ccf:Antibody',
#                         'producer': 'Nolan Lab',
#                         'recombinant': 'N'},
#                        {'antibody_type': 'Primary',
#                         'catalog_number': '333802',
#                         'clonality': 'Monoclonal',
#                         'clone_id': 'Y1/82A',
#                         'conjugate': 'Oligonucleotide',
#                         'detects': [{'protein_id': ['HGNC:1693'],
#                                      'rationale': 'Expressed by many subsets '
#                                                   'of myeloid cells including '
#                                                   'proinflammatory M1 '
#                                                   'macrophages. This marker '
#                                                   'represents a prioritized '
#                                                   'target in the intestine '
#                                                   'OMAP.'}],
#                         'fluorescent': 'Cy5',
#                         'host': 'Mouse',
#                         'id': 'https://identifiers.org/RRID:AB_1089058',
#                         'isotype': 'IgG2b kappa',
#                         'parent_class': 'ccf:Antibody',
#                         'producer': 'BioLegend',
#                         'recombinant': 'N'},
#                        {'antibody_type': 'Primary',
#                         'catalog_number': 'NBP2-34674',
#                         'clonality': 'Monoclonal',
#                         'clone_id': 'LK2H10 + PHE5 + CGA/414',
#                         'conjugate': 'Oligonucleotide',
#                         'detects': [{'protein_id': ['HGNC:1929'],
#                                      'rationale': 'Used for identification of '
#                                                   'neural cells and '
#                                                   'neuroendocrine cells. This '
#                                                   'marker represents a '
#                                                   'prioritized target in the '
#                                                   'intestine OMAP.'}],
#                         'fluorescent': 'AF488',
#                         'host': 'Mouse',
#                         'id': 'https://identifiers.org/RRID:AB_2864388',
#                         'isotype': 'IgG1 kappa',
#                         'parent_class': 'ccf:Antibody',
#                         'producer': 'Novus Biologicals',
#                         'recombinant': 'N'},
#                        {'antibody_type': 'Primary',
#                         'catalog_number': '354902',
#                         'clonality': 'Monoclonal',
#                         'clone_id': 'Bu32',
#                         'conjugate': 'Oligonucleotide',
#                         'detects': [{'protein_id': ['HGNC:2336'],
#                                      'rationale': 'Used for identification of '
#                                                   'B cells and follicular '
#                                                   'dendritic cells in '
#                                                   'gut-associated lymphoid '
#                                                   'tissue (GALT). This marker '
#                                                   'represents a prioritized '
#                                                   'target in the intestine '
#                                                   'OMAP.'}],
#                         'fluorescent': 'Cy3',
#                         'host': 'Mouse',
#                         'id': 'https://identifiers.org/RRID:AB_11219188',
#                         'isotype': 'IgG1 kappa',
#                         'parent_class': 'ccf:Antibody',
#                         'producer': 'BioLegend',
#                         'recombinant': 'N'},
#                        {'antibody_type': 'Primary',
#                         'catalog_number': 'NB120-11197',
#                         'clonality': 'Monoclonal',
#                         'clone_id': '996/1',
#                         'conjugate': 'Oligonucleotide',
#                         'detects': [{'protein_id': ['HGNC:7512'],
#                                      'rationale': 'Used for identification of '
#                                                   'goblet cells. This marker '
#                                                   'represents a prioritized '
#                                                   'target in the intestine '
#                                                   'OMAP.'}],
#                         'fluorescent': 'Cy5',
#                         'host': 'Mouse',
#                         'id': 'https://identifiers.org/RRID:AB_791261',
#                         'isotype': 'IgG1',
#                         'parent_class': 'ccf:Antibody',
#                         'producer': 'Novus Biologicals',
#                         'recombinant': 'N'},
#                        {'antibody_type': 'Primary',
#                         'catalog_number': '555444',
#                         'clonality': 'Monoclonal',
#                         'clone_id': 'WM59',
#                         'conjugate': 'Oligonucleotide',
#                         'detects': [{'protein_id': ['HGNC:8823'],
#                                      'rationale': 'Used for visualization of '
#                                                   'blood endothelial cells and '
#                                                   'vessels. This marker '
#                                                   'represents a prioritized '
#                                                   'target in the intestine '
#                                                   'OMAP.'}],
#                         'fluorescent': 'Cy3',
#                         'host': 'Mouse',
#                         'id': 'https://identifiers.org/RRID:AB_395837',
#                         'isotype': 'IgG1 kappa',
#                         'parent_class': 'ccf:Antibody',
#                         'producer': 'BD Biosciences',
#                         'recombinant': 'N'},
#                        {'antibody_type': 'Primary',
#                         'catalog_number': '555514',
#                         'clonality': 'Monoclonal',
#                         'clone_id': 'B159',
#                         'conjugate': 'Oligonucleotide',
#                         'detects': [{'protein_id': ['HGNC:7656'],
#                                      'rationale': 'Used for identification of '
#                                                   'NK cells and neural cells. '
#                                                   'This marker represents a '
#                                                   'prioritized target in the '
#                                                   'intestine OMAP.'}],
#                         'fluorescent': 'Cy5',
#                         'host': 'Mouse',
#                         'id': 'https://identifiers.org/RRID:AB_395904',
#                         'isotype': 'IgG1 kappa',
#                         'parent_class': 'ccf:Antibody',
#                         'producer': 'BD Biosciences',
#                         'recombinant': 'N'},
#                        {'antibody_type': 'Primary',
#                         'catalog_number': '555453',
#                         'clonality': 'Monoclonal',
#                         'clone_id': 'CB38 (NL07)',
#                         'conjugate': 'Oligonucleotide',
#                         'detects': [{'protein_id': ['HGNC:1663'],
#                                      'rationale': 'Used for visualization of '
#                                                   'blood and lymphatic '
#                                                   'endothelial cells and '
#                                                   'vessels.'}],
#                         'fluorescent': 'Cy3',
#                         'host': 'Mouse',
#                         'id': 'https://identifiers.org/RRID:AB_395846',
#                         'isotype': 'IgM kappa',
#                         'parent_class': 'ccf:Antibody',
#                         'producer': 'BD Biosciences',
#                         'recombinant': 'N'},
#                        {'antibody_type': 'Primary',
#                         'catalog_number': 'AF4254',
#                         'clonality': 'Polyclonal',
#                         'clone_id': 'null',
#                         'conjugate': 'Oligonucleotide',
#                         'detects': [{'protein_id': ['HGNC:18259'],
#                                      'rationale': 'Used for identification of '
#                                                   'early secretory goblet '
#                                                   'cells.'}],
#                         'fluorescent': 'Cy5',
#                         'host': 'Sheep',
#                         'id': 'https://identifiers.org/RRID:AB_2129678',
#                         'isotype': 'IgG',
#                         'parent_class': 'ccf:Antibody',
#                         'producer': 'R&D Systems',
#                         'recombinant': 'N'},
#                        {'antibody_type': 'Primary',
#                         'catalog_number': '310902',
#                         'clonality': 'Monoclonal',
#                         'clone_id': 'FN50',
#                         'conjugate': 'Oligonucleotide',
#                         'detects': [{'protein_id': ['HGNC:1694'],
#                                      'rationale': 'Used to define a particular '
#                                                   'T cell activation state.'}],
#                         'fluorescent': 'Cy3',
#                         'host': 'Mouse',
#                         'id': 'https://identifiers.org/RRID:AB_314837',
#                         'isotype': 'IgG1 kappa',
#                         'parent_class': 'ccf:Antibody',
#                         'producer': 'BioLegend',
#                         'recombinant': 'N'},
#                        {'antibody_type': 'Primary',
#                         'catalog_number': '356502',
#                         'clonality': 'Monoclonal',
#                         'clone_id': 'MI15',
#                         'conjugate': 'Oligonucleotide',
#                         'detects': [{'protein_id': ['HGNC:10658'],
#                                      'rationale': 'Key marker for plasma cells '
#                                                   'and broadly expressed on '
#                                                   'epithelial cells. This '
#                                                   'marker represents a core '
#                                                   'panel and prioritized '
#                                                   'target in the intestine '
#                                                   'OMAP.'}],
#                         'fluorescent': 'Cy5',
#                         'host': 'Mouse',
#                         'id': 'https://identifiers.org/RRID:AB_2561790',
#                         'isotype': 'IgG1 kappa',
#                         'parent_class': 'ccf:Antibody',
#                         'producer': 'BioLegend',
#                         'recombinant': 'N'},
#                        {'antibody_type': 'Primary',
#                         'catalog_number': '82630',
#                         'clonality': 'Monoclonal',
#                         'clone_id': 'D8G8H',
#                         'conjugate': 'Oligonucleotide',
#                         'detects': [{'protein_id': ['HGNC:11204'],
#                                      'rationale': 'Used for identification of '
#                                                   'transit amplifying cells.'}],
#                         'fluorescent': 'Cy3',
#                         'host': 'Rabbit',
#                         'id': 'https://identifiers.org/RRID:AB_2665492',
#                         'isotype': 'IgG',
#                         'parent_class': 'ccf:Antibody',
#                         'producer': 'Cell Signaling Technology',
#                         'recombinant': 'N'},
#                        {'antibody_type': 'Primary',
#                         'catalog_number': '344702',
#                         'clonality': 'Monoclonal',
#                         'clone_id': 'SK1',
#                         'conjugate': 'Oligonucleotide',
#                         'detects': [{'protein_id': ['HGNC:1706'],
#                                      'rationale': 'Used for identification of '
#                                                   'CD8+ T cells. This marker '
#                                                   'represents a prioritized '
#                                                   'target in the intestine '
#                                                   'OMAP.'}],
#                         'fluorescent': 'Cy5',
#                         'host': 'Mouse',
#                         'id': 'https://identifiers.org/RRID:AB_1877104',
#                         'isotype': 'IgG1 kappa',
#                         'parent_class': 'ccf:Antibody',
#                         'producer': 'BioLegend',
#                         'recombinant': 'N'},
#                        {'antibody_type': 'Primary',
#                         'catalog_number': '328302',
#                         'clonality': 'Monoclonal',
#                         'clone_id': 'TS2/7',
#                         'conjugate': 'Oligonucleotide',
#                         'detects': [{'protein_id': ['HGNC:6134'],
#                                      'rationale': 'Expressed by stromal cells '
#                                                   'as well as smooth muscle '
#                                                   'cells'}],
#                         'fluorescent': 'Cy3',
#                         'host': 'Mouse',
#                         'id': 'https://identifiers.org/RRID:AB_1236385',
#                         'isotype': 'IgG1 kappa',
#                         'parent_class': 'ccf:Antibody',
#                         'producer': 'BioLegend',
#                         'recombinant': 'N'},
#                        {'antibody_type': 'Primary',
#                         'catalog_number': '555734',
#                         'clonality': 'Monoclonal',
#                         'clone_id': 'GoH3',
#                         'conjugate': 'Oligonucleotide',
#                         'detects': [{'protein_id': ['HGNC:6142'],
#                                      'rationale': 'Used for visualization of '
#                                                   'intestinal crypt stem '
#                                                   'cells.'}],
#                         'fluorescent': 'Cy5',
#                         'host': 'Rat',
#                         'id': 'https://identifiers.org/RRID:AB_2296273',
#                         'isotype': 'IgG2a kappa',
# ...
#                                                         'type_of': ['https://identifiers.org/RRID:AB_314390']},
#                                            'cycle_number': 18,
#                                            'id': 'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#AB_314390-1074414146496433',
#                                            'is_core_panel': True,
#                                            'label': 'AB_314390 antibody, no '
#                                                     'lot number, unknown '
#                                                     'dilution factor or '
#                                                     'concentration value',
#                                            'type_of': ['ExperimentUsedAntibody'],
#                                            'used_by_experiment': 'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#OMAP-2'},
#                                           {'based_on': {'id': 'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#AB_2864404-1077174372164811',
#                                                         'label': 'AB_2864404 '
#                                                                  'antibody, no '
#                                                                  'lot number',
#                                                         'type_of': ['https://identifiers.org/RRID:AB_2864404']},
#                                            'cycle_number': 18,
#                                            'id': 'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#AB_2864404-1430936489554380',
#                                            'is_core_panel': False,
#                                            'label': 'AB_2864404 antibody, no '
#                                                     'lot number, unknown '
#                                                     'dilution factor or '
#                                                     'concentration value',
#                                            'type_of': ['ExperimentUsedAntibody'],
#                                            'used_by_experiment': 'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#OMAP-2'}]},
#                      {'cycle_number': 19,
#                       'id': 'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#OMAP-2-cycle-19',
#                       'label': 'OMAP-2 experiment, Cycle 19',
#                       'type_of': ['ExperimentCycle'],
#                       'uses_antibodies': [{'based_on': {'id': 'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#AB_312953-3628286052290954',
#                                                         'label': 'AB_312953 '
#                                                                  'antibody, no '
#                                                                  'lot number',
#                                                         'type_of': ['https://identifiers.org/RRID:AB_312953']},
#                                            'cycle_number': 19,
#                                            'id': 'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#AB_312953-4621916403448874',
#                                            'is_core_panel': False,
#                                            'label': 'AB_312953 antibody, no '
#                                                     'lot number, unknown '
#                                                     'dilution factor or '
#                                                     'concentration value',
#                                            'type_of': ['ExperimentUsedAntibody'],
#                                            'used_by_experiment': 'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#OMAP-2'},
#                                           {'based_on': {'id': 'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#AB_1595511-8218651269212012',
#                                                         'label': 'AB_1595511 '
#                                                                  'antibody, no '
#                                                                  'lot number',
#                                                         'type_of': ['https://identifiers.org/RRID:AB_1595511']},
#                                            'cycle_number': 19,
#                                            'id': 'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#AB_1595511-3684999004422082',
#                                            'is_core_panel': False,
#                                            'label': 'AB_1595511 antibody, no '
#                                                     'lot number, unknown '
#                                                     'dilution factor or '
#                                                     'concentration value',
#                                            'type_of': ['ExperimentUsedAntibody'],
#                                            'used_by_experiment': 'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#OMAP-2'}]},
#                      {'cycle_number': 20,
#                       'id': 'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#OMAP-2-cycle-20',
#                       'label': 'OMAP-2 experiment, Cycle 20',
#                       'type_of': ['ExperimentCycle'],
#                       'uses_antibodies': [{'based_on': {'id': 'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#AB_305584-712930562677742',
#                                                         'label': 'AB_305584 '
#                                                                  'antibody, no '
#                                                                  'lot number',
#                                                         'type_of': ['https://identifiers.org/RRID:AB_305584']},
#                                            'cycle_number': 20,
#                                            'id': 'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#AB_305584-6910626779445887',
#                                            'is_core_panel': False,
#                                            'label': 'AB_305584 antibody, no '
#                                                     'lot number, unknown '
#                                                     'dilution factor or '
#                                                     'concentration value',
#                                            'type_of': ['ExperimentUsedAntibody'],
#                                            'used_by_experiment': 'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#OMAP-2'},
#                                           {'based_on': {'id': 'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#AB_1088991-3432560673788074',
#                                                         'label': 'AB_1088991 '
#                                                                  'antibody, no '
#                                                                  'lot number',
#                                                         'type_of': ['https://identifiers.org/RRID:AB_1088991']},
#                                            'cycle_number': 20,
#                                            'id': 'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#AB_1088991-6334464320959347',
#                                            'is_core_panel': False,
#                                            'label': 'AB_1088991 antibody, no '
#                                                     'lot number, unknown '
#                                                     'dilution factor or '
#                                                     'concentration value',
#                                            'type_of': ['ExperimentUsedAntibody'],
#                                            'used_by_experiment': 'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#OMAP-2'}]},
#                      {'cycle_number': 21,
#                       'id': 'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#OMAP-2-cycle-21',
#                       'label': 'OMAP-2 experiment, Cycle 21',
#                       'type_of': ['ExperimentCycle'],
#                       'uses_antibodies': [{'based_on': {'id': 'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#AB_2785318-3642090445101841',
#                                                         'label': 'AB_2785318 '
#                                                                  'antibody, no '
#                                                                  'lot number',
#                                                         'type_of': ['https://identifiers.org/RRID:AB_2785318']},
#                                            'cycle_number': 21,
#                                            'id': 'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#AB_2785318-7149283824331138',
#                                            'is_core_panel': False,
#                                            'label': 'AB_2785318 antibody, no '
#                                                     'lot number, unknown '
#                                                     'dilution factor or '
#                                                     'concentration value',
#                                            'type_of': ['ExperimentUsedAntibody'],
#                                            'used_by_experiment': 'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#OMAP-2'},
#                                           {'based_on': {'id': 'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#AB_571923-1399387391822932',
#                                                         'label': 'AB_571923 '
#                                                                  'antibody, no '
#                                                                  'lot number',
#                                                         'type_of': ['https://identifiers.org/RRID:AB_571923']},
#                                            'cycle_number': 21,
#                                            'id': 'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#AB_571923-617509891043083',
#                                            'is_core_panel': False,
#                                            'label': 'AB_571923 antibody, no '
#                                                     'lot number, unknown '
#                                                     'dilution factor or '
#                                                     'concentration value',
#                                            'type_of': ['ExperimentUsedAntibody'],
#                                            'used_by_experiment': 'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#OMAP-2'}]},
#                      {'cycle_number': 22,
#                       'id': 'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#OMAP-2-cycle-22',
#                       'label': 'OMAP-2 experiment, Cycle 22',
#                       'type_of': ['ExperimentCycle'],
#                       'uses_antibodies': [{'based_on': {'id': 'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#AB_2864387-966040463005385',
#                                                         'label': 'AB_2864387 '
#                                                                  'antibody, no '
#                                                                  'lot number',
#                                                         'type_of': ['https://identifiers.org/RRID:AB_2864387']},
#                                            'cycle_number': 22,
#                                            'id': 'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#AB_2864387-8317519485290844',
#                                            'is_core_panel': False,
#                                            'label': 'AB_2864387 antibody, no '
#                                                     'lot number, unknown '
#                                                     'dilution factor or '
#                                                     'concentration value',
#                                            'type_of': ['ExperimentUsedAntibody'],
#                                            'used_by_experiment': 'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#OMAP-2'}]}],
#           'experiment': {'author_orcid': ['0000-0001-9961-7673'],
#                          'has_cycle': ['https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#OMAP-2-cycle-2',
#                                        'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#OMAP-2-cycle-3',
#                                        'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#OMAP-2-cycle-4',
#                                        'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#OMAP-2-cycle-5',
#                                        'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#OMAP-2-cycle-6',
#                                        'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#OMAP-2-cycle-7',
#                                        'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#OMAP-2-cycle-8',
#                                        'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#OMAP-2-cycle-9',
#                                        'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#OMAP-2-cycle-10',
#                                        'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#OMAP-2-cycle-11',
#                                        'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#OMAP-2-cycle-12',
#                                        'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#OMAP-2-cycle-13',
#                                        'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#OMAP-2-cycle-14',
#                                        'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#OMAP-2-cycle-15',
#                                        'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#OMAP-2-cycle-16',
#                                        'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#OMAP-2-cycle-17',
#                                        'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#OMAP-2-cycle-18',
#                                        'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#OMAP-2-cycle-19',
#                                        'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#OMAP-2-cycle-20',
#                                        'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#OMAP-2-cycle-21',
#                                        'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#OMAP-2-cycle-22'],
#                          'id': 'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#OMAP-2',
#                          'label': 'OMAP-2 experiment',
#                          'protocol_doi': ['https://doi.org/10.1038/s41596-021-00556-8'],
#                          'sample_organ': 'UBERON:0000160',
#                          'study_method': 'CODEX',
#                          'tissue_preservation': 'Fresh frozen',
#                          'type_of': ['MultiplexedAntibodyBasedImagingExperiment']}},
#  'iri': 'https://purl.humanatlas.io/omap/2-intestine-codex',
#  'metadata': {'created_by': ['https://github.com/hubmapconsortium/hra-do-processor'],
#               'creation_date': '2025-06-12',
#               'derived_from': 'https://lod.humanatlas.io/omap/2-intestine-codex/v1.6#raw-data',
#               'description': 'The graph representation of the OMAP-2 Organ '
#                              'Mapping Antibody Panel (OMAP) for Multiplexed '
#                              'Antibody-Based Imaging of Human Intestines with '
#                              'CODEX dataset.',
#               'license': 'https://creativecommons.org/licenses/by/4.0/',
#               'publisher': 'HuBMAP',
#               'see_also': 'https://lod.humanatlas.io/omap/2-intestine-codex/v1.6',
#               'title': '2-intestine-codex (v1.6) graph data',
#               'version': 'v1.6'}}

# %%
# let's inspect the result further
print(list(intestine_omap.keys()))    # keys
# Out:
# ['$schema', '@context', '@type', 'iri', 'metadata', 'data']

# %%
# let's look at the entire data
pprint(intestine_omap['data'])
# Out:
# {'antibody': [{'antibody_type': 'Primary',
#                'catalog_number': '556003',
#                'clonality': 'Monoclonal',
#                'clone_id': 'B56',
#                'conjugate': 'Oligonucleotide',
#                'detects': [{'protein_id': ['HGNC:7107'],
#                             'rationale': 'This marker does not define a '
#                                          'distinct cell type, but highlights '
#                                          'all proliferating cells, useful in '
#                                          'various diseases and transit '
#                                          'amplifying cells. Defines germinal '
#                                          'centers of gut-associated lymphoid '
#                                          'tissue (GALT). This marker '
#                                          'represents a prioritized target in '
#                                          'the intestine OMAP.'}],
#                'fluorescent': 'AF488',
#                'host': 'Mouse',
#                'id': 'https://identifiers.org/RRID:AB_396287',
#                'isotype': 'IgG1 kappa',
#                'parent_class': 'ccf:Antibody',
#                'producer': 'BD Biosciences',
#                'recombinant': 'N'},
#               {'antibody_type': 'Primary',
#                'catalog_number': 'BE0014',
#                'clonality': 'Monoclonal',
#                'clone_id': '7G7B6',
#                'conjugate': 'Oligonucleotide',
#                'detects': [{'protein_id': ['HGNC:6008'],
#                             'rationale': 'This marker can be used to identify '
#                                          'T regulatory cells. The inclusion of '
#                                          'FOXP3 is recommended to provide '
#                                          'greater confidence in the T '
#                                          'regulatory cell phenotype. This '
#                                          'marker represents a prioritized '
#                                          'target in the intestine OMAP.'}],
#                'fluorescent': 'Cy3',
#                'host': 'Mouse',
#                'id': 'https://identifiers.org/RRID:AB_1107617',
#                'isotype': 'IgG2a',
#                'parent_class': 'ccf:Antibody',
#                'producer': 'Bio X Cell',
#                'recombinant': 'N'},
#               {'antibody_type': 'Primary',
#                'catalog_number': '315602',
#                'clonality': 'Monoclonal',
#                'clone_id': 'MEM-108',
#                'conjugate': 'Oligonucleotide',
#                'detects': [{'protein_id': ['HGNC:11026'],
#                             'rationale': 'This marker does not define a '
#                                          'distinct cell type but instead '
#                                          'serves as a pan-membrane marker. It '
#                                          'can be used to segment most cells.'}],
#                'fluorescent': 'Cy5',
#                'host': 'Mouse',
#                'id': 'https://identifiers.org/RRID:AB_2302070',
#                'isotype': 'IgG1 kappa',
#                'parent_class': 'ccf:Antibody',
#                'producer': 'BioLegend',
#                'recombinant': 'N'},
#               {'antibody_type': 'Primary',
#                'catalog_number': '550513',
#                'clonality': 'Monoclonal',
#                'clone_id': 'RV202',
#                'conjugate': 'Oligonucleotide',
#                'detects': [{'protein_id': ['HGNC:12692'],
#                             'rationale': 'Defines stromal network of intestine '
#                                          'and serves as a pan-mesenchymal cell '
#                                          'marker. The combination of collagen '
#                                          'IV, pan-cytokeratin, alpha smooth '
#                                          'muscle actin, and vimentin can be '
#                                          'used to define the villi, crypts, '
#                                          'basal membrane, and lamina propria. '
#                                          'This marker represents a core panel '
#                                          'and prioritized target in the '
#                                          'intestine OMAP.'}],
#                'fluorescent': 'AF488',
#                'host': 'Mouse',
#                'id': 'https://identifiers.org/RRID:AB_393716',
#                'isotype': 'IgG1',
#                'parent_class': 'ccf:Antibody',
#                'producer': 'BD Biosciences',
#                'recombinant': 'N'},
#               {'antibody_type': 'Primary',
#                'catalog_number': '322302',
#                'clonality': 'Monoclonal',
#                'clone_id': 'HCD57',
#                'conjugate': 'Oligonucleotide',
#                'detects': [{'protein_id': ['HGNC:921'],
#                             'rationale': 'Used for identification of NK '
#                                          'cells.'}],
#                'fluorescent': 'Cy3',
#                'host': 'Mouse',
#                'id': 'https://identifiers.org/RRID:AB_535988',
#                'isotype': 'IgM',
#                'parent_class': 'ccf:Antibody',
#                'producer': 'BioLegend',
#                'recombinant': 'N'},
#               {'antibody_type': 'Primary',
#                'catalog_number': '320802',
#                'clonality': 'Monoclonal',
#                'clone_id': '1D11',
#                'conjugate': 'Oligonucleotide',
#                'detects': [{'protein_id': ['HGNC:18788'],
#                             'rationale': 'Used for identification of NK '
#                                          'cells.'}],
#                'fluorescent': 'Cy5',
#                'host': 'Mouse',
#                'id': 'https://identifiers.org/RRID:AB_492956',
#                'isotype': 'IgG1 kappa',
#                'parent_class': 'ccf:Antibody',
#                'producer': 'BioLegend',
#                'recombinant': 'N'},
#               {'antibody_type': 'Primary',
#                'catalog_number': '343102',
#                'clonality': 'Monoclonal',
#                'clone_id': 'CD7-6B7',
#                'conjugate': 'Oligonucleotide',
#                'detects': [{'protein_id': ['HGNC:1695'],
#                             'rationale': 'Used for identification of NK and T '
#                                          'cells.'}],
#                'fluorescent': 'AF488',
#                'host': 'Mouse',
#                'id': 'https://identifiers.org/RRID:AB_1659214',
#                'isotype': 'IgG2a kappa',
#                'parent_class': 'ccf:Antibody',
#                'producer': 'BioLegend',
#                'recombinant': 'N'},
#               {'antibody_type': 'Primary',
#                'catalog_number': '357402',
#                'clonality': 'Monoclonal',
#                'clone_id': 'A161A1',
#                'conjugate': 'Oligonucleotide',
#                'detects': [{'protein_id': ['HGNC:1678'],
#                             'rationale': 'Used for identification of CD4+ T '
#                                          'cells. This marker represents a '
#                                          'prioritized target in the intestine '
#                                          'OMAP.'}],
#                'fluorescent': 'Cy3',
#                'host': 'Rat',
#                'id': 'https://identifiers.org/RRID:AB_2561907',
#                'isotype': 'IgG2b kappa',
#                'parent_class': 'ccf:Antibody',
#                'producer': 'BioLegend',
#                'recombinant': 'N'},
#               {'antibody_type': 'Primary',
#                'catalog_number': '555410',
#                'clonality': 'Monoclonal',
#                'clone_id': 'HIB19',
#                'conjugate': 'Oligonucleotide',
#                'detects': [{'protein_id': ['HGNC:1633'],
#                             'rationale': 'Essential marker of B cells and also '
#                                          'identifies plasma cells. Defines B '
#                                          'cell follicles of gut-associated '
#                                          'lymphoid tissue (GALT). This marker '
#                                          'represents a core panel and '
#                                          'prioritized target in the intestine '
#                                          'OMAP.'}],
#                'fluorescent': 'Cy5',
#                'host': 'Mouse',
#                'id': 'https://identifiers.org/RRID:AB_395810',
#                'isotype': 'IgG1 kappa',
#                'parent_class': 'ccf:Antibody',
#                'producer': 'BD Biosciences',
#                'recombinant': 'N'},
#               {'antibody_type': 'Primary',
#                'catalog_number': '307651',
#                'clonality': 'Monoclonal',
#                'clone_id': 'L243',
#                'conjugate': 'Oligonucleotide',
#                'detects': [{'protein_id': ['HGNC:1697'],
#                             'rationale': 'Used for identification of antigen '
#                                          'presenting cells (B cells, dendritic '
#                                          'cells, macrophages). Defines B cell '
#                                          'follicles (HLA-DR+) and germinal '
#                                          'centers (HLA-DR++) of gut-associated '
#                                          'lymphoid tissue (GALT).'}],
#                'fluorescent': 'AF488',
#                'host': 'Mouse',
#                'id': 'https://identifiers.org/RRID:AB_2562826',
#                'isotype': 'IgG2a kappa',
#                'parent_class': 'ccf:Antibody',
#                'producer': 'BioLegend',
#                'recombinant': 'N'},
#               {'antibody_type': 'Primary',
#                'catalog_number': '555391',
#                'clonality': 'Monoclonal',
#                'clone_id': 'B-ly6',
#                'conjugate': 'Oligonucleotide',
#                'detects': [{'protein_id': ['HGNC:6152'],
#                             'rationale': 'Used for identification of dendritic '
#                                          'cells. This marker represents a '
#                                          'prioritized target in the intestine '
#                                          'OMAP.'}],
#                'fluorescent': 'Cy3',
#                'host': 'Mouse',
#                'id': 'https://identifiers.org/RRID:AB_395792',
#                'isotype': 'IgG1 kappa',
#                'parent_class': 'ccf:Antibody',
#                'producer': 'BD Biosciences',
#                'recombinant': 'N'},
#               {'antibody_type': 'Primary',
#                'catalog_number': '339902',
#                'clonality': 'Monoclonal',
#                'clone_id': 'HP-3G10',
#                'conjugate': 'Oligonucleotide',
#                'detects': [{'protein_id': ['HGNC:6373'],
#                             'rationale': 'Used for identification of NK cells '
#                                          'and other innate lymphoid cells.'}],
#                'fluorescent': 'Cy5',
#                'host': 'Mouse',
#                'id': 'https://identifiers.org/RRID:AB_1501090',
#                'isotype': 'IgG1 kappa',
#                'parent_class': 'ccf:Antibody',
#                'producer': 'BioLegend',
#                'recombinant': 'N'},
#               {'antibody_type': 'Primary',
#                'catalog_number': 'NBP1-47483',
#                'clonality': 'Monoclonal',
#                'clone_id': '7H12',
#                'conjugate': 'Oligonucleotide',
#                'detects': [{'protein_id': ['HGNC:11506'],
#                             'rationale': 'Used for identification of neural '
#                                          'cells. This marker represents a '
#                                          'prioritized target in the intestine '
#                                          'OMAP.'}],
#                'fluorescent': 'AF488',
#                'host': 'Mouse',
#                'id': 'https://identifiers.org/RRID:AB_10010435',
#                'isotype': 'IgG1',
#                'parent_class': 'ccf:Antibody',
#                'producer': 'Novus Biologicals',
#                'recombinant': 'N'},
#               {'antibody_type': 'Primary',
#                'catalog_number': '343602',
#                'clonality': 'Monoclonal',
#                'clone_id': '561',
#                'conjugate': 'Oligonucleotide',
#                'detects': [{'protein_id': ['HGNC:1662'],
#                             'rationale': 'Used for visualization of blood and '
#                                          'lymphatic endothelial cells and '
#                                          'vessels. Identifies fibroblasts of '
#                                          'the muscularis propria and '
#                                          'submucosa.'}],
#                'fluorescent': 'Cy3',
#                'host': 'Mouse',
#                'id': 'https://identifiers.org/RRID:AB_1732014',
#                'isotype': 'IgG2a kappa',
#                'parent_class': 'ccf:Antibody',
#                'producer': 'BioLegend',
#                'recombinant': 'N'},
#               {'antibody_type': 'Primary',
#                'catalog_number': '555404',
#                'clonality': 'Monoclonal',
#                'clone_id': '3G8',
#                'conjugate': 'Oligonucleotide',
#                'detects': [{'protein_id': ['HGNC:3619'],
#                             'rationale': 'Used for identification of '
#                                          'neutrophils. This marker represents '
#                                          'a prioritized target in the '
#                                          'intestine OMAP.'}],
#                'fluorescent': 'Cy5',
#                'host': 'Mouse',
#                'id': 'https://identifiers.org/RRID:AB_395804',
#                'isotype': 'IgG1 kappa',
#                'parent_class': 'ccf:Antibody',
#                'producer': 'BD Biosciences',
#                'recombinant': 'N'},
#               {'antibody_type': 'Primary',
#                'catalog_number': '555400',
#                'clonality': 'Monoclonal',
#                'clone_id': 'HI98',
#                'conjugate': 'Oligonucleotide',
#                'detects': [{'protein_id': ['HGNC:4015'],
#                             'rationale': 'Used for identification of '
#                                          'neutrophils. Expressed by some '
#                                          'Paneth cells. This marker represents '
#                                          'a prioritized target in the '
#                                          'intestine OMAP.'}],
#                'fluorescent': 'AF488',
#                'host': 'Mouse',
#                'id': 'https://identifiers.org/RRID:AB_395800',
#                'isotype': 'IgM kappa',
#                'parent_class': 'ccf:Antibody',
#                'producer': 'BD Biosciences',
#                'recombinant': 'N'},
#               {'antibody_type': 'Primary',
#                'catalog_number': '13-0300',
#                'clonality': 'Monoclonal',
#                'clone_id': '2.2B10',
#                'conjugate': 'Oligonucleotide',
#                'detects': [{'protein_id': ['HGNC:3590'],
#                             'rationale': 'Used for identification of '
#                                          'fibroblasts.'}],
#                'fluorescent': 'Cy3',
#                'host': 'Rat',
#                'id': 'https://identifiers.org/RRID:AB_2532994',
#                'isotype': 'IgG2a kappa',
#                'parent_class': 'ccf:Antibody',
#                'producer': 'Thermo Fisher Scientific',
#                'recombinant': 'N'},
#               {'antibody_type': 'Primary',
#                'catalog_number': '554527',
#                'clonality': 'Monoclonal',
#                'clone_id': '7G3',
#                'conjugate': 'Oligonucleotide',
#                'detects': [{'protein_id': ['HGNC:6012'],
#                             'rationale': 'Expressed by plasmacytoid dendritic '
#                                          'cells.'}],
#                'fluorescent': 'Cy5',
#                'host': 'Mouse',
#                'id': 'https://identifiers.org/RRID:AB_395455',
#                'isotype': 'IgG2a kappa',
#                'parent_class': 'ccf:Antibody',
#                'producer': 'BD Biosciences',
#                'recombinant': 'N'},
#               {'antibody_type': 'Primary',
#                'catalog_number': '551354',
#                'clonality': 'Monoclonal',
#                'clone_id': 'B1.1/CD66',
#                'conjugate': 'Oligonucleotide',
#                'detects': [{'protein_id': ['HGNC:1814'],
#                             'rationale': 'Used for identification of mature '
#                                          'epithelial cells and expressed on '
#                                          'neutrophils'}],
#                'fluorescent': 'AF488',
#                'host': 'Mouse',
#                'id': 'https://identifiers.org/RRID:AB_394166',
#                'isotype': 'IgG2a kappa',
#                'parent_class': 'ccf:Antibody',
#                'producer': 'BD Biosciences',
#                'recombinant': 'N'},
#               {'antibody_type': 'Primary',
#                'catalog_number': '300402',
#                'clonality': 'Monoclonal',
#                'clone_id': 'UCHT1',
#                'conjugate': 'Oligonucleotide',
#                'detects': [{'protein_id': ['HGNC:1674'],
#                             'rationale': 'Essential marker of T cells. Defines '
#                                          'T cell zone of gut-associated '
#                                          'lymphoid tissues (GALT). This marker '
#                                          'represents a core panel and '
#                                          'prioritized target in the intestine '
#                                          'OMAP.'}],
#                'fluorescent': 'Cy3',
#                'host': 'Mouse',
#                'id': 'https://identifiers.org/RRID:AB_314056',
#                'isotype': 'IgG1 kappa',
#                'parent_class': 'ccf:Antibody',
#                'producer': 'BioLegend',
#                'recombinant': 'N'},
#               {'antibody_type': 'Primary',
#                'catalog_number': '304202',
#                'clonality': 'Monoclonal',
#                'clone_id': 'UCHL1',
#                'conjugate': 'Oligonucleotide',
#                'detects': [{'protein_id': ['HGNC:9666'],
#                             'rationale': 'CD45RO is used to define a '
#                                          'particular T cell activation '
#                                          'state.'}],
#                'fluorescent': 'Cy5',
#                'host': 'Mouse',
#                'id': 'https://identifiers.org/RRID:AB_314418',
#                'isotype': 'IgG2a kappa',
#                'parent_class': 'ccf:Antibody',
#                'producer': 'BioLegend',
#                'recombinant': 'N'},
#               {'antibody_type': 'Primary',
#                'catalog_number': '356602',
#                'clonality': 'Monoclonal',
#                'clone_id': 'HB-7',
#                'conjugate': 'Oligonucleotide',
#                'detects': [{'protein_id': ['HGNC:1667'],
#                             'rationale': 'Used for identification of plasma '
#                                          'cells. This marker represents a '
#                                          'prioritized target in the intestine '
#                                          'OMAP.'}],
#                'fluorescent': 'AF488',
#                'host': 'Mouse',
#                'id': 'https://identifiers.org/RRID:AB_2561794',
#                'isotype': 'IgG1 kappa',
#                'parent_class': 'ccf:Antibody',
#                'producer': 'BioLegend',
#                'recombinant': 'N'},
#               {'antibody_type': 'Primary',
#                'catalog_number': '328102',
#                'clonality': 'Monoclonal',
#                'clone_id': '50000000000',
#                'conjugate': 'Oligonucleotide',
#                'detects': [{'protein_id': ['HGNC:11801'],
#                             'rationale': 'Expressed by stromal cells as well '
#                                          'as blood endothelial cells, T cells, '
#                                          'and NK cells.'}],
#                'fluorescent': 'Cy3',
#                'host': 'Mouse',
#                'id': 'https://identifiers.org/RRID:AB_940393',
#                'isotype': 'IgG1 kappa',
#                'parent_class': 'ccf:Antibody',
#                'producer': 'BioLegend',
#                'recombinant': 'N'},
#               {'antibody_type': 'Primary',
#                'catalog_number': '351302',
#                'clonality': 'Monoclonal',
#                'clone_id': 'A019D5',
#                'conjugate': 'Oligonucleotide',
#                'detects': [{'protein_id': ['HGNC:6024'],
#                             'rationale': 'Used to define a particular T cell '
#                                          'activation state.'}],
#                'fluorescent': 'Cy5',
#                'host': 'Mouse',
#                'id': 'https://identifiers.org/RRID:AB_10718513',
#                'isotype': 'IgG1 kappa',
#                'parent_class': 'ccf:Antibody',
#                'producer': 'BioLegend',
#                'recombinant': 'N'},
#               {'antibody_type': 'Primary',
#                'catalog_number': '14-9760-82',
#                'clonality': 'Monoclonal',
#                'clone_id': '1A4',
#                'conjugate': 'Oligonucleotide',
#                'detects': [{'protein_id': ['HGNC:130'],
#                             'rationale': 'Used for identification of smooth '
#                                          'muscle cells. The combination of '
#                                          'collagen IV, pan-cytokeratin, alpha '
#                                          'smooth muscle actin, and vimentin '
#                                          'can be used to define the villi, '
#                                          'crypts, basal membrane, and lamina '
#                                          'propria. This marker represents a '
#                                          'core panel and prioritized target in '
#                                          'the intestine OMAP.'}],
#                'fluorescent': 'AF488',
#                'host': 'Mouse',
#                'id': 'https://identifiers.org/RRID:AB_2572996',
#                'isotype': 'IgG2a kappa',
#                'parent_class': 'ccf:Antibody',
#                'producer': 'Thermo Fisher Scientific',
#                'recombinant': 'N'},
#               {'antibody_type': 'Primary',
#                'catalog_number': '555713',
#                'clonality': 'Monoclonal',
#                'clone_id': 'YB5.B8',
#                'conjugate': 'Oligonucleotide',
#                'detects': [{'protein_id': ['HGNC:6342'],
#                             'rationale': 'Used for identification of '
#                                          'Interstitial cells of Cajal and mast '
#                                          'cells. This marker represents a '
#                                          'prioritized target in the intestine '
#                                          'OMAP.'}],
#                'fluorescent': 'Cy3',
#                'host': 'Mouse',
#                'id': 'https://identifiers.org/RRID:AB_2131466',
#                'isotype': 'IgG1 kappa',
#                'parent_class': 'ccf:Antibody',
#                'producer': 'BD Biosciences',
#                'recombinant': 'N'},
#               {'antibody_type': 'Primary',
#                'catalog_number': '914204',
#                'clonality': 'Monoclonal',
#                'clone_id': 'AE-1/AE-3',
#                'conjugate': 'Oligonucleotide',
#                'detects': [{'protein_id': ['HGNC:6413',
#                                            'HGNC:6416',
#                                            'HGNC:6421',
#                                            'HGNC:6423',
#                                            'HGNC:6436',
#                                            'HGNC:6412',
#                                            'HGNC:6439',
#                                            'HGNC:6440',
#                                            'HGNC:6441',
#                                            'HGNC:6442',
#                                            'HGNC:6445',
#                                            'HGNC:6446'],
#                             'rationale': 'Pan-epithelial marker for '
#                                          'segmentation of epithelial cells. '
#                                          'The combination of collagen IV, '
#                                          'pan-cytokeratin, alpha smooth muscle '
#                                          'actin, and vimentin can be used to '
#                                          'define the villi, crypts, basal '
#                                          'membrane, and lamina propria. This '
#                                          'marker represents a core panel and '
#                                          'prioritized target in the intestine '
#                                          'OMAP.'}],
#                'fluorescent': 'Cy5',
#                'host': 'Mouse',
#                'id': 'https://identifiers.org/RRID:AB_2616960',
#                'isotype': 'IgG1 kappa',
#                'parent_class': 'ccf:Antibody',
#                'producer': 'BioLegend',
#                'recombinant': 'N'},
#               {'antibody_type': 'Primary',
#                'catalog_number': 'V2372SAF',
#                'clonality': 'Monoclonal',
#                'clone_id': 'MUC1/955',
#                'conjugate': 'Oligonucleotide',
#                'detects': [{'protein_id': ['HGNC:7508'],
#                             'rationale': 'Marker for epithelial cells, '
#                                          'specifically enterocytes.'}],
#                'fluorescent': 'AF488',
#                'host': 'Mouse',
#                'id': 'https://identifiers.org/RRID:AB_2864392',
#                'isotype': 'IgG1 kappa',
#                'parent_class': 'ccf:Antibody',
#                'producer': 'NSJ Bioreagents',
#                'recombinant': 'N'},
#               {'antibody_type': 'Primary',
#                'catalog_number': '4267',
#                'clonality': 'Monoclonal',
#                'clone_id': 'D38B1',
#                'conjugate': 'Oligonucleotide',
#                'detects': [{'protein_id': ['HGNC:1806'],
#                             'rationale': 'Nuclear marker of intestinal '
#                                          'epithelial cells expressed by early '
#                                          'epithelial cells.'}],
#                'fluorescent': 'Cy3',
#                'host': 'Rabbit',
#                'id': 'https://identifiers.org/RRID:AB_2864405',
#                'isotype': 'IgG',
#                'parent_class': 'ccf:Antibody',
#                'producer': 'Nolan Lab',
#                'recombinant': 'N'},
#               {'antibody_type': 'Primary',
#                'catalog_number': '333802',
#                'clonality': 'Monoclonal',
#                'clone_id': 'Y1/82A',
#                'conjugate': 'Oligonucleotide',
#                'detects': [{'protein_id': ['HGNC:1693'],
#                             'rationale': 'Expressed by many subsets of myeloid '
#                                          'cells including proinflammatory M1 '
#                                          'macrophages. This marker represents '
#                                          'a prioritized target in the '
#                                          'intestine OMAP.'}],
#                'fluorescent': 'Cy5',
#                'host': 'Mouse',
#                'id': 'https://identifiers.org/RRID:AB_1089058',
#                'isotype': 'IgG2b kappa',
#                'parent_class': 'ccf:Antibody',
#                'producer': 'BioLegend',
#                'recombinant': 'N'},
#               {'antibody_type': 'Primary',
#                'catalog_number': 'NBP2-34674',
#                'clonality': 'Monoclonal',
#                'clone_id': 'LK2H10 + PHE5 + CGA/414',
#                'conjugate': 'Oligonucleotide',
#                'detects': [{'protein_id': ['HGNC:1929'],
#                             'rationale': 'Used for identification of neural '
#                                          'cells and neuroendocrine cells. This '
#                                          'marker represents a prioritized '
#                                          'target in the intestine OMAP.'}],
#                'fluorescent': 'AF488',
#                'host': 'Mouse',
#                'id': 'https://identifiers.org/RRID:AB_2864388',
#                'isotype': 'IgG1 kappa',
#                'parent_class': 'ccf:Antibody',
#                'producer': 'Novus Biologicals',
#                'recombinant': 'N'},
#               {'antibody_type': 'Primary',
#                'catalog_number': '354902',
#                'clonality': 'Monoclonal',
#                'clone_id': 'Bu32',
#                'conjugate': 'Oligonucleotide',
#                'detects': [{'protein_id': ['HGNC:2336'],
#                             'rationale': 'Used for identification of B cells '
#                                          'and follicular dendritic cells in '
#                                          'gut-associated lymphoid tissue '
#                                          '(GALT). This marker represents a '
#                                          'prioritized target in the intestine '
#                                          'OMAP.'}],
#                'fluorescent': 'Cy3',
#                'host': 'Mouse',
#                'id': 'https://identifiers.org/RRID:AB_11219188',
#                'isotype': 'IgG1 kappa',
#                'parent_class': 'ccf:Antibody',
#                'producer': 'BioLegend',
#                'recombinant': 'N'},
#               {'antibody_type': 'Primary',
#                'catalog_number': 'NB120-11197',
#                'clonality': 'Monoclonal',
#                'clone_id': '996/1',
#                'conjugate': 'Oligonucleotide',
#                'detects': [{'protein_id': ['HGNC:7512'],
#                             'rationale': 'Used for identification of goblet '
#                                          'cells. This marker represents a '
#                                          'prioritized target in the intestine '
#                                          'OMAP.'}],
#                'fluorescent': 'Cy5',
#                'host': 'Mouse',
#                'id': 'https://identifiers.org/RRID:AB_791261',
#                'isotype': 'IgG1',
#                'parent_class': 'ccf:Antibody',
#                'producer': 'Novus Biologicals',
#                'recombinant': 'N'},
#               {'antibody_type': 'Primary',
#                'catalog_number': '555444',
#                'clonality': 'Monoclonal',
#                'clone_id': 'WM59',
#                'conjugate': 'Oligonucleotide',
#                'detects': [{'protein_id': ['HGNC:8823'],
#                             'rationale': 'Used for visualization of blood '
#                                          'endothelial cells and vessels. This '
#                                          'marker represents a prioritized '
#                                          'target in the intestine OMAP.'}],
#                'fluorescent': 'Cy3',
#                'host': 'Mouse',
#                'id': 'https://identifiers.org/RRID:AB_395837',
#                'isotype': 'IgG1 kappa',
#                'parent_class': 'ccf:Antibody',
#                'producer': 'BD Biosciences',
#                'recombinant': 'N'},
#               {'antibody_type': 'Primary',
#                'catalog_number': '555514',
#                'clonality': 'Monoclonal',
#                'clone_id': 'B159',
#                'conjugate': 'Oligonucleotide',
#                'detects': [{'protein_id': ['HGNC:7656'],
#                             'rationale': 'Used for identification of NK cells '
#                                          'and neural cells. This marker '
#                                          'represents a prioritized target in '
#                                          'the intestine OMAP.'}],
#                'fluorescent': 'Cy5',
#                'host': 'Mouse',
#                'id': 'https://identifiers.org/RRID:AB_395904',
#                'isotype': 'IgG1 kappa',
#                'parent_class': 'ccf:Antibody',
#                'producer': 'BD Biosciences',
#                'recombinant': 'N'},
#               {'antibody_type': 'Primary',
#                'catalog_number': '555453',
#                'clonality': 'Monoclonal',
#                'clone_id': 'CB38 (NL07)',
#                'conjugate': 'Oligonucleotide',
#                'detects': [{'protein_id': ['HGNC:1663'],
#                             'rationale': 'Used for visualization of blood and '
#                                          'lymphatic endothelial cells and '
#                                          'vessels.'}],
#                'fluorescent': 'Cy3',
#                'host': 'Mouse',
#                'id': 'https://identifiers.org/RRID:AB_395846',
#                'isotype': 'IgM kappa',
#                'parent_class': 'ccf:Antibody',
#                'producer': 'BD Biosciences',
#                'recombinant': 'N'},
#               {'antibody_type': 'Primary',
#                'catalog_number': 'AF4254',
#                'clonality': 'Polyclonal',
#                'clone_id': 'null',
#                'conjugate': 'Oligonucleotide',
#                'detects': [{'protein_id': ['HGNC:18259'],
#                             'rationale': 'Used for identification of early '
#                                          'secretory goblet cells.'}],
#                'fluorescent': 'Cy5',
#                'host': 'Sheep',
#                'id': 'https://identifiers.org/RRID:AB_2129678',
#                'isotype': 'IgG',
#                'parent_class': 'ccf:Antibody',
#                'producer': 'R&D Systems',
#                'recombinant': 'N'},
#               {'antibody_type': 'Primary',
#                'catalog_number': '310902',
#                'clonality': 'Monoclonal',
#                'clone_id': 'FN50',
#                'conjugate': 'Oligonucleotide',
#                'detects': [{'protein_id': ['HGNC:1694'],
#                             'rationale': 'Used to define a particular T cell '
#                                          'activation state.'}],
#                'fluorescent': 'Cy3',
#                'host': 'Mouse',
#                'id': 'https://identifiers.org/RRID:AB_314837',
#                'isotype': 'IgG1 kappa',
#                'parent_class': 'ccf:Antibody',
#                'producer': 'BioLegend',
#                'recombinant': 'N'},
#               {'antibody_type': 'Primary',
#                'catalog_number': '356502',
#                'clonality': 'Monoclonal',
#                'clone_id': 'MI15',
#                'conjugate': 'Oligonucleotide',
#                'detects': [{'protein_id': ['HGNC:10658'],
#                             'rationale': 'Key marker for plasma cells and '
#                                          'broadly expressed on epithelial '
#                                          'cells. This marker represents a core '
#                                          'panel and prioritized target in the '
#                                          'intestine OMAP.'}],
#                'fluorescent': 'Cy5',
#                'host': 'Mouse',
#                'id': 'https://identifiers.org/RRID:AB_2561790',
#                'isotype': 'IgG1 kappa',
#                'parent_class': 'ccf:Antibody',
#                'producer': 'BioLegend',
#                'recombinant': 'N'},
#               {'antibody_type': 'Primary',
#                'catalog_number': '82630',
#                'clonality': 'Monoclonal',
#                'clone_id': 'D8G8H',
#                'conjugate': 'Oligonucleotide',
#                'detects': [{'protein_id': ['HGNC:11204'],
#                             'rationale': 'Used for identification of transit '
#                                          'amplifying cells.'}],
#                'fluorescent': 'Cy3',
#                'host': 'Rabbit',
#                'id': 'https://identifiers.org/RRID:AB_2665492',
#                'isotype': 'IgG',
#                'parent_class': 'ccf:Antibody',
#                'producer': 'Cell Signaling Technology',
#                'recombinant': 'N'},
#               {'antibody_type': 'Primary',
#                'catalog_number': '344702',
#                'clonality': 'Monoclonal',
#                'clone_id': 'SK1',
#                'conjugate': 'Oligonucleotide',
#                'detects': [{'protein_id': ['HGNC:1706'],
#                             'rationale': 'Used for identification of CD8+ T '
#                                          'cells. This marker represents a '
#                                          'prioritized target in the intestine '
#                                          'OMAP.'}],
#                'fluorescent': 'Cy5',
#                'host': 'Mouse',
#                'id': 'https://identifiers.org/RRID:AB_1877104',
#                'isotype': 'IgG1 kappa',
#                'parent_class': 'ccf:Antibody',
#                'producer': 'BioLegend',
#                'recombinant': 'N'},
#               {'antibody_type': 'Primary',
#                'catalog_number': '328302',
#                'clonality': 'Monoclonal',
#                'clone_id': 'TS2/7',
#                'conjugate': 'Oligonucleotide',
#                'detects': [{'protein_id': ['HGNC:6134'],
#                             'rationale': 'Expressed by stromal cells as well '
#                                          'as smooth muscle cells'}],
#                'fluorescent': 'Cy3',
#                'host': 'Mouse',
#                'id': 'https://identifiers.org/RRID:AB_1236385',
#                'isotype': 'IgG1 kappa',
#                'parent_class': 'ccf:Antibody',
#                'producer': 'BioLegend',
#                'recombinant': 'N'},
#               {'antibody_type': 'Primary',
#                'catalog_number': '555734',
#                'clonality': 'Monoclonal',
#                'clone_id': 'GoH3',
#                'conjugate': 'Oligonucleotide',
#                'detects': [{'protein_id': ['HGNC:6142'],
#                             'rationale': 'Used for visualization of intestinal '
#                                          'crypt stem cells.'}],
#                'fluorescent': 'Cy5',
#                'host': 'Rat',
#                'id': 'https://identifiers.org/RRID:AB_2296273',
#                'isotype': 'IgG2a kappa',
#                'parent_class': 'ccf:Antibody',
#                'producer': 'BD Biosciences',
#                'recombinant': 'N'},
#               {'antibody_type': 'Primary',
#                'catalog_number': '304002',
#                'clonality': 'Monoclonal',
#                'clone_id': 'HI30',
#                'conjugate': 'Oligonucleotide',
#                'detects': [{'protein_id': ['HGNC:9666'],
#                             'rationale': 'This marker cannot be used to define '
#                                          'a specific anatomical structure but '
#                                          'is expressed by all hematopoietic '
#                                          'cells. This marker represents a '
#                                          'prioritized target in the intestine '
#                                          'OMAP and can be used for downstream '
#                                          'image analysis.'}],
#                'fluorescent': 'Cy3',
#                'host': 'Mouse',
#                'id': 'https://identifiers.org/RRID:AB_314390',
#                'isotype': 'IgG1 kappa',
#                'parent_class': 'ccf:Antibody',
#                'producer': 'BioLegend',
#                'recombinant': 'N'},
#               {'antibody_type': 'Primary',
#                'catalog_number': '226M',
#                'clonality': 'Monoclonal',
#                'clone_id': '124',
#                'conjugate': 'Oligonucleotide',
#                'detects': [{'protein_id': ['HGNC:990'],
#                             'rationale': 'Used for visualization of various '
#                                          'immune cells.'}],
#                'fluorescent': 'Cy5',
#                'host': 'Mouse',
#                'id': 'https://identifiers.org/RRID:AB_2864404',
#                'isotype': 'IgG1',
#                'parent_class': 'ccf:Antibody',
#                'producer': 'Nolan Lab',
#                'recombinant': 'N'},
#               {'antibody_type': 'Primary',
#                'catalog_number': '103002',
#                'clonality': 'Monoclonal',
#                'clone_id': 'IM7',
#                'conjugate': 'Oligonucleotide',
#                'detects': [{'protein_id': ['HGNC:1681'],
#                             'rationale': 'This antibody labels endothelial '
#                                          'cells, mesenchymal cells, and '
#                                          'reports the activation status of '
#                                          'several immune cell subsets.'}],
#                'fluorescent': 'Cy3',
#                'host': 'Rat',
#                'id': 'https://identifiers.org/RRID:AB_312953',
#                'isotype': 'IgG2b kappa',
#                'parent_class': 'ccf:Antibody',
#                'producer': 'BioLegend',
#                'recombinant': 'N'},
#               {'antibody_type': 'Primary',
#                'catalog_number': '337002',
#                'clonality': 'Monoclonal',
#                'clone_id': 'NC-08',
#                'conjugate': 'Oligonucleotide',
#                'detects': [{'protein_id': ['HGNC:29602'],
#                             'rationale': 'Used for visualization of lacteals '
#                                          '(lymphatic endothelial cells) and '
#                                          'fibroblasts. This marker represents '
#                                          'a prioritized target in the '
#                                          'intestine OMAP.'}],
#                'fluorescent': 'Cy5',
#                'host': 'Rat',
#                'id': 'https://identifiers.org/RRID:AB_1595511',
#                'isotype': 'IgG2a delta',
#                'parent_class': 'ccf:Antibody',
#                'producer': 'BioLegend',
#                'recombinant': 'N'},
#               {'antibody_type': 'Primary',
#                'catalog_number': 'ab6586',
#                'clonality': 'Polyclonal',
#                'clone_id': 'null',
#                'conjugate': 'Oligonucleotide',
#                'detects': [{'protein_id': ['HGNC:2202'],
#                             'rationale': 'Used for visualization of the basal '
#                                          'membrane and extracellular matrix. '
#                                          'The combination of collagen IV, '
#                                          'pan-cytokeratin, alpha smooth muscle '
#                                          'actin, and vimentin can be used to '
#                                          'define the villi, crypts, basal '
#                                          'membrane, and lamina propria.'}],
#                'fluorescent': 'Cy3',
#                'host': 'Rabbit',
#                'id': 'https://identifiers.org/RRID:AB_305584',
#                'isotype': 'IgG',
#                'parent_class': 'ccf:Antibody',
#                'producer': 'Abcam',
#                'recombinant': 'N'},
#               {'antibody_type': 'Primary',
#                'catalog_number': '333602',
#                'clonality': 'Monoclonal',
#                'clone_id': 'GHI/61',
#                'conjugate': 'Oligonucleotide',
#                'detects': [{'protein_id': ['HGNC:1631'],
#                             'rationale': 'Used for identification of M2 '
#                                          'macrophages. This marker represents '
#                                          'a prioritized target in the '
#                                          'intestine OMAP.'}],
#                'fluorescent': 'Cy5',
#                'host': 'Mouse',
#                'id': 'https://identifiers.org/RRID:AB_1088991',
#                'isotype': 'IgG1 kappa',
#                'parent_class': 'ccf:Antibody',
#                'producer': 'BioLegend',
#                'recombinant': 'N'},
#               {'antibody_type': 'Primary',
#                'catalog_number': 'MA5-29457',
#                'clonality': 'Monoclonal',
#                'clone_id': '12',
#                'conjugate': 'Oligonucleotide',
#                'detects': [{'protein_id': ['HGNC:17190'],
#                             'rationale': 'Used for identification of '
#                                          'intestinal crypt stem cells of small '
#                                          'intestine.'}],
#                'fluorescent': 'Cy3',
#                'host': 'Mouse',
#                'id': 'https://identifiers.org/RRID:AB_2785318',
#                'isotype': 'IgG1',
#                'parent_class': 'ccf:Antibody',
#                'producer': 'Thermo Fisher Scientific',
#                'recombinant': 'N'},
#               {'antibody_type': 'Primary',
#                'catalog_number': '321102',
#                'clonality': 'Monoclonal',
#                'clone_id': '15-2',
#                'conjugate': 'Oligonucleotide',
#                'detects': [{'protein_id': ['HGNC:7228'],
#                             'rationale': 'Used for identification of M2 '
#                                          'macrophages. This marker represents '
#                                          'a prioritized target in the '
#                                          'intestine OMAP.'}],
#                'fluorescent': 'Cy5',
#                'host': 'Mouse',
#                'id': 'https://identifiers.org/RRID:AB_571923',
#                'isotype': 'IgG1 kappa',
#                'parent_class': 'ccf:Antibody',
#                'producer': 'BioLegend',
#                'recombinant': 'N'},
#               {'antibody_type': 'Primary',
#                'catalog_number': 'ab245946',
#                'clonality': 'Monoclonal',
#                'clone_id': 'EPR14309(B)',
#                'conjugate': 'Oligonucleotide',
#                'detects': [{'protein_id': ['HGNC:2764'],
#                             'rationale': 'Used for identification of Paneth '
#                                          'cells. This marker represents a '
#                                          'prioritized target in the intestine '
#                                          'OMAP.'}],
#                'fluorescent': 'Cy5',
#                'host': 'Rabbit',
#                'id': 'https://identifiers.org/RRID:AB_2864387',
#                'isotype': 'IgG',
#                'parent_class': 'ccf:Antibody',
#                'producer': 'Abcam',
#                'recombinant': 'N'}],
#  'antibody_panel': {'contains_antibodies': ['https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#AB_396287-1238822726926556',
#                                             'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#AB_1107617-6189540603307881',
#                                             'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#AB_2302070-7505316030893278',
#                                             'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#AB_393716-5125054391566302',
#                                             'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#AB_535988-6117805016155763',
#                                             'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#AB_492956-7413901318988616',
#                                             'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#AB_1659214-40822957593926',
#                                             'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#AB_2561907-6229463466120024',
#                                             'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#AB_395810-7208735305888454',
#                                             'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#AB_2562826-1563639817251138',
#                                             'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#AB_395792-1865291136465905',
#                                             'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#AB_1501090-6869476408873212',
#                                             'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#AB_10010435-4397661090486488',
# ...
#                                   'label': 'AB_1877104 antibody, no lot '
#                                            'number, unknown dilution factor or '
#                                            'concentration value',
#                                   'type_of': ['ExperimentUsedAntibody'],
#                                   'used_by_experiment': 'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#OMAP-2'}]},
#             {'cycle_number': 17,
#              'id': 'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#OMAP-2-cycle-17',
#              'label': 'OMAP-2 experiment, Cycle 17',
#              'type_of': ['ExperimentCycle'],
#              'uses_antibodies': [{'based_on': {'id': 'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#AB_1236385-1024175034174168',
#                                                'label': 'AB_1236385 antibody, '
#                                                         'no lot number',
#                                                'type_of': ['https://identifiers.org/RRID:AB_1236385']},
#                                   'cycle_number': 17,
#                                   'id': 'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#AB_1236385-2077137909072975',
#                                   'is_core_panel': False,
#                                   'label': 'AB_1236385 antibody, no lot '
#                                            'number, unknown dilution factor or '
#                                            'concentration value',
#                                   'type_of': ['ExperimentUsedAntibody'],
#                                   'used_by_experiment': 'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#OMAP-2'},
#                                  {'based_on': {'id': 'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#AB_2296273-2857878868778954',
#                                                'label': 'AB_2296273 antibody, '
#                                                         'no lot number',
#                                                'type_of': ['https://identifiers.org/RRID:AB_2296273']},
#                                   'cycle_number': 17,
#                                   'id': 'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#AB_2296273-5035421996496596',
#                                   'is_core_panel': False,
#                                   'label': 'AB_2296273 antibody, no lot '
#                                            'number, unknown dilution factor or '
#                                            'concentration value',
#                                   'type_of': ['ExperimentUsedAntibody'],
#                                   'used_by_experiment': 'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#OMAP-2'}]},
#             {'cycle_number': 18,
#              'id': 'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#OMAP-2-cycle-18',
#              'label': 'OMAP-2 experiment, Cycle 18',
#              'type_of': ['ExperimentCycle'],
#              'uses_antibodies': [{'based_on': {'id': 'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#AB_314390-2575382664842598',
#                                                'label': 'AB_314390 antibody, '
#                                                         'no lot number',
#                                                'type_of': ['https://identifiers.org/RRID:AB_314390']},
#                                   'cycle_number': 18,
#                                   'id': 'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#AB_314390-1074414146496433',
#                                   'is_core_panel': True,
#                                   'label': 'AB_314390 antibody, no lot number, '
#                                            'unknown dilution factor or '
#                                            'concentration value',
#                                   'type_of': ['ExperimentUsedAntibody'],
#                                   'used_by_experiment': 'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#OMAP-2'},
#                                  {'based_on': {'id': 'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#AB_2864404-1077174372164811',
#                                                'label': 'AB_2864404 antibody, '
#                                                         'no lot number',
#                                                'type_of': ['https://identifiers.org/RRID:AB_2864404']},
#                                   'cycle_number': 18,
#                                   'id': 'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#AB_2864404-1430936489554380',
#                                   'is_core_panel': False,
#                                   'label': 'AB_2864404 antibody, no lot '
#                                            'number, unknown dilution factor or '
#                                            'concentration value',
#                                   'type_of': ['ExperimentUsedAntibody'],
#                                   'used_by_experiment': 'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#OMAP-2'}]},
#             {'cycle_number': 19,
#              'id': 'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#OMAP-2-cycle-19',
#              'label': 'OMAP-2 experiment, Cycle 19',
#              'type_of': ['ExperimentCycle'],
#              'uses_antibodies': [{'based_on': {'id': 'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#AB_312953-3628286052290954',
#                                                'label': 'AB_312953 antibody, '
#                                                         'no lot number',
#                                                'type_of': ['https://identifiers.org/RRID:AB_312953']},
#                                   'cycle_number': 19,
#                                   'id': 'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#AB_312953-4621916403448874',
#                                   'is_core_panel': False,
#                                   'label': 'AB_312953 antibody, no lot number, '
#                                            'unknown dilution factor or '
#                                            'concentration value',
#                                   'type_of': ['ExperimentUsedAntibody'],
#                                   'used_by_experiment': 'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#OMAP-2'},
#                                  {'based_on': {'id': 'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#AB_1595511-8218651269212012',
#                                                'label': 'AB_1595511 antibody, '
#                                                         'no lot number',
#                                                'type_of': ['https://identifiers.org/RRID:AB_1595511']},
#                                   'cycle_number': 19,
#                                   'id': 'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#AB_1595511-3684999004422082',
#                                   'is_core_panel': False,
#                                   'label': 'AB_1595511 antibody, no lot '
#                                            'number, unknown dilution factor or '
#                                            'concentration value',
#                                   'type_of': ['ExperimentUsedAntibody'],
#                                   'used_by_experiment': 'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#OMAP-2'}]},
#             {'cycle_number': 20,
#              'id': 'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#OMAP-2-cycle-20',
#              'label': 'OMAP-2 experiment, Cycle 20',
#              'type_of': ['ExperimentCycle'],
#              'uses_antibodies': [{'based_on': {'id': 'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#AB_305584-712930562677742',
#                                                'label': 'AB_305584 antibody, '
#                                                         'no lot number',
#                                                'type_of': ['https://identifiers.org/RRID:AB_305584']},
#                                   'cycle_number': 20,
#                                   'id': 'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#AB_305584-6910626779445887',
#                                   'is_core_panel': False,
#                                   'label': 'AB_305584 antibody, no lot number, '
#                                            'unknown dilution factor or '
#                                            'concentration value',
#                                   'type_of': ['ExperimentUsedAntibody'],
#                                   'used_by_experiment': 'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#OMAP-2'},
#                                  {'based_on': {'id': 'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#AB_1088991-3432560673788074',
#                                                'label': 'AB_1088991 antibody, '
#                                                         'no lot number',
#                                                'type_of': ['https://identifiers.org/RRID:AB_1088991']},
#                                   'cycle_number': 20,
#                                   'id': 'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#AB_1088991-6334464320959347',
#                                   'is_core_panel': False,
#                                   'label': 'AB_1088991 antibody, no lot '
#                                            'number, unknown dilution factor or '
#                                            'concentration value',
#                                   'type_of': ['ExperimentUsedAntibody'],
#                                   'used_by_experiment': 'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#OMAP-2'}]},
#             {'cycle_number': 21,
#              'id': 'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#OMAP-2-cycle-21',
#              'label': 'OMAP-2 experiment, Cycle 21',
#              'type_of': ['ExperimentCycle'],
#              'uses_antibodies': [{'based_on': {'id': 'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#AB_2785318-3642090445101841',
#                                                'label': 'AB_2785318 antibody, '
#                                                         'no lot number',
#                                                'type_of': ['https://identifiers.org/RRID:AB_2785318']},
#                                   'cycle_number': 21,
#                                   'id': 'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#AB_2785318-7149283824331138',
#                                   'is_core_panel': False,
#                                   'label': 'AB_2785318 antibody, no lot '
#                                            'number, unknown dilution factor or '
#                                            'concentration value',
#                                   'type_of': ['ExperimentUsedAntibody'],
#                                   'used_by_experiment': 'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#OMAP-2'},
#                                  {'based_on': {'id': 'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#AB_571923-1399387391822932',
#                                                'label': 'AB_571923 antibody, '
#                                                         'no lot number',
#                                                'type_of': ['https://identifiers.org/RRID:AB_571923']},
#                                   'cycle_number': 21,
#                                   'id': 'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#AB_571923-617509891043083',
#                                   'is_core_panel': False,
#                                   'label': 'AB_571923 antibody, no lot number, '
#                                            'unknown dilution factor or '
#                                            'concentration value',
#                                   'type_of': ['ExperimentUsedAntibody'],
#                                   'used_by_experiment': 'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#OMAP-2'}]},
#             {'cycle_number': 22,
#              'id': 'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#OMAP-2-cycle-22',
#              'label': 'OMAP-2 experiment, Cycle 22',
#              'type_of': ['ExperimentCycle'],
#              'uses_antibodies': [{'based_on': {'id': 'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#AB_2864387-966040463005385',
#                                                'label': 'AB_2864387 antibody, '
#                                                         'no lot number',
#                                                'type_of': ['https://identifiers.org/RRID:AB_2864387']},
#                                   'cycle_number': 22,
#                                   'id': 'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#AB_2864387-8317519485290844',
#                                   'is_core_panel': False,
#                                   'label': 'AB_2864387 antibody, no lot '
#                                            'number, unknown dilution factor or '
#                                            'concentration value',
#                                   'type_of': ['ExperimentUsedAntibody'],
#                                   'used_by_experiment': 'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#OMAP-2'}]}],
#  'experiment': {'author_orcid': ['0000-0001-9961-7673'],
#                 'has_cycle': ['https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#OMAP-2-cycle-2',
#                               'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#OMAP-2-cycle-3',
#                               'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#OMAP-2-cycle-4',
#                               'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#OMAP-2-cycle-5',
#                               'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#OMAP-2-cycle-6',
#                               'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#OMAP-2-cycle-7',
#                               'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#OMAP-2-cycle-8',
#                               'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#OMAP-2-cycle-9',
#                               'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#OMAP-2-cycle-10',
#                               'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#OMAP-2-cycle-11',
#                               'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#OMAP-2-cycle-12',
#                               'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#OMAP-2-cycle-13',
#                               'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#OMAP-2-cycle-14',
#                               'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#OMAP-2-cycle-15',
#                               'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#OMAP-2-cycle-16',
#                               'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#OMAP-2-cycle-17',
#                               'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#OMAP-2-cycle-18',
#                               'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#OMAP-2-cycle-19',
#                               'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#OMAP-2-cycle-20',
#                               'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#OMAP-2-cycle-21',
#                               'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#OMAP-2-cycle-22'],
#                 'id': 'https://purl.humanatlas.io/omap/2-intestine-codex/v1.6#OMAP-2',
#                 'label': 'OMAP-2 experiment',
#                 'protocol_doi': ['https://doi.org/10.1038/s41596-021-00556-8'],
#                 'sample_organ': 'UBERON:0000160',
#                 'study_method': 'CODEX',
#                 'tissue_preservation': 'Fresh frozen',
#                 'type_of': ['MultiplexedAntibodyBasedImagingExperiment']}}
